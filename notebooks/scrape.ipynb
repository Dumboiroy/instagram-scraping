# %%
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait


email_login = "alguitarmailbox@gmail.com"
password_login = "Guitar123456"
post_url = "https://www.instagram.com/p/C-HPL2mSrFV/"

browser = webdriver.Firefox()
browser.implicitly_wait(5)

# Opening Instagram
try:
    browser.get("https://www.instagram.com/accounts/login/?hl=en")
    print("Opened Instagram.")

    browser.implicitly_wait(5)

    # login credentials
    print("finding login credentials")
    username_input = browser.find_element(By.NAME, "username")
    password_input = browser.find_element(By.NAME, "password")

    print("sending login credentials")
    username_input.send_keys(email_login)
    password_input.send_keys(password_login)

    # Finding Login button
    try:
        login_link = browser.find_element(By.XPATH, "//button/div[text()='Log in']")
    except Exception as e:
        print("Error finding login button:", repr(e))

    # Clicking on Login button
    print("clicking login button")
    try:
        login_link.click()
    except Exception as e:
        print("Error clicking login button:", repr(e))

    # Wait for 2FA to load
    while True:
        if "two_factor" not in browser.current_url:
            print("waiting for 2FA to load...")
            sleep(1)
        else:
            break

    # 2FA
    print(browser.current_url)
    if "two_factor" in browser.current_url:
        print("Two factor authentication required.")
        while True:
            # Await Two factor authentication
            if "two_factor" not in browser.current_url:
                break
            else:
                print("waiting...")
                sleep(1)
    sleep(1)

    # Opening Post
    try:
        post_url = post_url
        browser.get(post_url)
        print("Opened post.")
    except Exception as e:
        print("Error opening post:", repr(e))
except Exception as e:
        print("Error opening Instagram:", repr(e))
# Out:
# Opened Instagram.
# finding login credentials
# sending login credentials
# clicking login button
# waiting for 2FA to load...
# waiting for 2FA to load...
# waiting for 2FA to load...
# https://www.instagram.com/accounts/login/two_factor?hl=en&next=%2F
# Two factor authentication required.
# waiting...
# waiting...
# waiting...
# waiting...
# waiting...
# waiting...
# waiting...
# waiting...
# waiting...
# waiting...
# waiting...
# waiting...
# Opened post.

# %%
# getting all comments
try:
    comment_classes = "x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1uhb9sk x1plvlek xryxfnj x1iyjqo2 x2lwn1j xeuugli x1q0g3np xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1"

    comments = browser.find_elements(
        By.CSS_SELECTOR, f"div[class*='{comment_classes}']"
    )
    print("Found elements:", len(comments))

except Exception as e:
    print("Error finding comments:", repr(e))
# Out:
# Found elements: 16

# %%
for comment in comments:
    print(comment.text)
    print("=====================================")
# Out:
# luxelashes.sg
#  1d
# luxelashes' first anniversary giveaway??!!?! 🖤
#
# to thank you girls for being a part of my lashing journey, i am hosting a giveaway for the month of August!
#
# Stand a chance to win:
# ✨ Free lash set of your choice (3 winners)
# ✨ 50% off any lash set (3 winners)
# ✨ 20% off any lash set (5 winners)
# ✨ Lash shampoo kit (3 winners)
#
# All you have to do is
# 1. follow @luxelashes.sg on instagram
# 2. like & share this post on your story (for private accounts, please screenshot your story)
# 3. tag 3 friends in the comment section (1 comment = 1 chance)
# Bonus: book a slot in August for 5 extra chances!
#
# T&Cs
# -giveaway ends on 31 August 2024, 11.59pm
# -discounts will exclude add ons and removals
# -deposit will be required to reserve your slot (will be refunded after your appointment for free sets)
# -usual T&Cs apply
#
# #sglashes #sglash #sglashextensions #singaporelash #singaporelashes #singapore #singaporelashextensions #singaporelashextension #singaporebeauty #sgbeauty #sglashartist
# =====================================
# _xinzhi
#  12h
# @daynaatan @jadeaw_ @yinhuin 🫶🏻
# Reply
# =====================================
# chxryll_
#  1d
# @ljm.jpg @audrie.desu @jam.ie_ 👀👀
# Reply
# =====================================
# aa.udreyt_
#  1d
# @ji4xin_ @varelynnn.wq @melly_beanzzz
# Reply
# =====================================
# hrroyz
#  9h
# @weelin_n @dilys29 @constaaaancee
# Reply
# =====================================
# lenny.ang23
#  14h
# @naaadeline @angeliaaangg @yunis_yid ❤️
# Reply
# =====================================
# zinarita1
#  1d
# @coralcarol_coleslaw @ccaandicceee @sora.lovingyoga hope to win! ❤️
# Reply
# =====================================
# meereedeethe
#  1d
# @xinhuiiii @amychoon @cthhhhhh
# Reply
# =====================================
# shea.adn
#  1d
# @ssf40e @nrezzatee @n.iiraa 🍒
# Reply
# =====================================
# eggsoupverynice
#  1d
# @huejxy @puffymochiii @hxmilktea
# Reply
# =====================================
# charmainecps_
#  1d
# @_crystallarhs_ @bysharice @fonggkayy
# Reply
# =====================================
# nataliee.koh
#  12h
# @tjyingx @kyushu.white @jorin.seahh
# 1 like
# Reply
# =====================================
# michelleang33
#  6h
# @jessica_williama__77
# Reply
# =====================================
# peachyisbitchy
#  1d
# @sxtyen @ewvanz @haydontbemin
# Reply
# =====================================
# michelleang33
#  6h
# @nixlxin
# Reply
# =====================================
# michelleang33
#  6h
# Liked
# Reply
# =====================================

# %%
import pandas as pd

# %%
data = []
for comment in comments:
    data.append(comment.text)

# %%
df = pd.DataFrame(data, columns=["Comments"])
df = df.drop(index=0)

# %%
df = df['Comments'].str.split('\n', expand=True)

# %%
df
# Out:
#                   0     1                                                  2  \
# 1           _xinzhi   12h                    @daynaatan @jadeaw_ @yinhuin 🫶🏻
# 2          chxryll_    1d                  @ljm.jpg @audrie.desu @jam.ie_ 👀👀
# 3        aa.udreyt_    1d              @ji4xin_ @varelynnn.wq @melly_beanzzz
# 4            hrroyz    9h                  @weelin_n @dilys29 @constaaaancee
# 5       lenny.ang23   14h            @naaadeline @angeliaaangg @yunis_yid ❤️
# 6         zinarita1    1d  @coralcarol_coleslaw @ccaandicceee @sora.lovin...
# 7      meereedeethe    1d                     @xinhuiiii @amychoon @cthhhhhh
# 8          shea.adn    1d                      @ssf40e @nrezzatee @n.iiraa 🍒
# 9   eggsoupverynice    1d                   @huejxy @puffymochiii @hxmilktea
# 10    charmainecps_    1d              @_crystallarhs_ @bysharice @fonggkayy
# 11     nataliee.koh   12h                @tjyingx @kyushu.white @jorin.seahh
# 12    michelleang33    6h                              @jessica_williama__77
# 13   peachyisbitchy    1d                      @sxtyen @ewvanz @haydontbemin
# 14    michelleang33    6h                                           @nixlxin
# 15    michelleang33    6h                                              Liked
#
#          3      4
# 1    Reply   None
# 2    Reply   None
# 3    Reply   None
# 4    Reply   None
# 5    Reply   None
# 6    Reply   None
# 7    Reply   None
# 8    Reply   None
# 9    Reply   None
# 10   Reply   None
# 11  1 like  Reply
# 12   Reply   None
# 13   Reply   None
# 14   Reply   None
# 15   Reply   None
